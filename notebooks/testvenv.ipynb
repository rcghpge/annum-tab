# %% [markdown]
# # test venv stacks on bsd

# %%
import os

print(os.getcwd())
# Out:
# /home/rc/Desktop/annum-tab/notebooks

# %%
import sys
sys.path.append("../src")  

from annum_tab.tests.venv import detect_python_stack

info = detect_python_stack()
for k, v in info.items():
    print(f"{k}: {v}")
# Out:
# system: FreeBSD
# python_executable: /usr/local/bin/python3.11
# venv: generic venv (VIRTUAL_ENV: /home/rc/Desktop/annum-tab/.venv)
# pixi_installed: False
# pdm_installed: True
# conda_installed: False
# poetry_installed: False
